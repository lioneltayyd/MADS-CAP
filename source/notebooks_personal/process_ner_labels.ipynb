# %% [markdown]
# # Process NER Labels.

# %%
# Python module. 
import os 
import numpy as np
import pandas as pd
from collections import defaultdict

# Change the current directory from (./notebook) to root directory. 
if os.getcwd().split("/")[-1] != "MADS-M2-estimating-news-impact-on-financial-market": 
	os.chdir("../..")

# For clearing safe warnings. Not important. 
from IPython.display import clear_output

# Custom configs. 
from source.config_py.config import DIR_DATASET, DIR_DATASET_COLLECTION, DIR_DATASET_LABELLINGS

# Preview. 
print(os.getcwd())
# Out:
# /Users/lioneltay/Dropbox/Courses/michigan_mads/SIADS_694_695_milestone_2_Eric_Gilbert/submission/MADS-M2-financial-news-personalisation

# %% [markdown]
# ## Configurations (general).

# %%
# Pandas DF config. 
pd.set_option("display.max_rows", 50, "display.max_columns", 50, "display.max_colwidth", 50)

# For clearing the output. Not important. 
clear_output()

# %% [markdown]
# ## Experimental preprocessing on sentence split and span.

# %%
# Create random sentence to test the processing steps. 
df_entities_exm = pd.DataFrame({
	"id": [1], "sentence": ["This is a random; 'sentence', just for exploration 'only', don't bother-about/the grammer mistake."]
}) 
df_entities_exm["token"] = df_entities_exm["sentence"].str.split(r"\b") 

# Preview. 
df_entities_exm
# Out:
#    id                                           sentence  \
# 0   1  This is a random; 'sentence', just for explora...
#
#                                                token
# 0  [, This,  , is,  , a,  , random, ; ', sentence...

# %%
# Expand the list of token into subsequent rows. 
df_token_exm = df_entities_exm.explode(column="token") 

# Preview. 
df_token_exm
# Out:
#    id                                           sentence        token
# 0   1  This is a random; 'sentence', just for explora...
# 0   1  This is a random; 'sentence', just for explora...         This
# 0   1  This is a random; 'sentence', just for explora...
# 0   1  This is a random; 'sentence', just for explora...           is
# 0   1  This is a random; 'sentence', just for explora...
# 0   1  This is a random; 'sentence', just for explora...            a
# 0   1  This is a random; 'sentence', just for explora...
# 0   1  This is a random; 'sentence', just for explora...       random
# 0   1  This is a random; 'sentence', just for explora...          ; '
# 0   1  This is a random; 'sentence', just for explora...     sentence
# 0   1  This is a random; 'sentence', just for explora...          ',
# 0   1  This is a random; 'sentence', just for explora...         just
# 0   1  This is a random; 'sentence', just for explora...
# 0   1  This is a random; 'sentence', just for explora...          for
# 0   1  This is a random; 'sentence', just for explora...
# 0   1  This is a random; 'sentence', just for explora...  exploration
# 0   1  This is a random; 'sentence', just for explora...            '
# 0   1  This is a random; 'sentence', just for explora...         only
# 0   1  This is a random; 'sentence', just for explora...          ',
# 0   1  This is a random; 'sentence', just for explora...          don
# 0   1  This is a random; 'sentence', just for explora...            '
# 0   1  This is a random; 'sentence', just for explora...            t
# 0   1  This is a random; 'sentence', just for explora...
# 0   1  This is a random; 'sentence', just for explora...       bother
# 0   1  This is a random; 'sentence', just for explora...            -
# 0   1  This is a random; 'sentence', just for explora...        about
# 0   1  This is a random; 'sentence', just for explora...            /
# 0   1  This is a random; 'sentence', just for explora...          the
# 0   1  This is a random; 'sentence', just for explora...
# 0   1  This is a random; 'sentence', just for explora...      grammer
# 0   1  This is a random; 'sentence', just for explora...
# 0   1  This is a random; 'sentence', just for explora...      mistake
# 0   1  This is a random; 'sentence', just for explora...            .

# %%
# Get the str length to calculate span (str indices) at the start and end later. 
# We need span to extract the entities. Other third-party NLP pipelines 
# also require spans as input. 
df_token_exm["len"] = df_token_exm["token"].str.len()

# Get the span for each token for each sentence. 
df_token_exm["span_end"] = df_token_exm.groupby("id").agg(span_end=pd.NamedAgg(column="len", aggfunc=np.cumsum)) 
df_token_exm["span_beg"] = df_token_exm.groupby("id")["span_end"].shift(periods=1) 
df_token_exm["span_beg"] = df_token_exm["span_beg"].fillna(0.0).astype(int) 
df_token_exm["span"] = df_token_exm[["span_beg", "span_end"]].values.tolist() 

# Preview. 
df_token_exm
# Out:
#    id                                           sentence        token  len  \
# 0   1  This is a random; 'sentence', just for explora...                 0
# 0   1  This is a random; 'sentence', just for explora...         This    4
# 0   1  This is a random; 'sentence', just for explora...                 1
# 0   1  This is a random; 'sentence', just for explora...           is    2
# 0   1  This is a random; 'sentence', just for explora...                 1
# 0   1  This is a random; 'sentence', just for explora...            a    1
# 0   1  This is a random; 'sentence', just for explora...                 1
# 0   1  This is a random; 'sentence', just for explora...       random    6
# 0   1  This is a random; 'sentence', just for explora...          ; '    3
# 0   1  This is a random; 'sentence', just for explora...     sentence    8
# 0   1  This is a random; 'sentence', just for explora...          ',     3
# 0   1  This is a random; 'sentence', just for explora...         just    4
# 0   1  This is a random; 'sentence', just for explora...                 1
# 0   1  This is a random; 'sentence', just for explora...          for    3
# 0   1  This is a random; 'sentence', just for explora...                 1
# 0   1  This is a random; 'sentence', just for explora...  exploration   11
# 0   1  This is a random; 'sentence', just for explora...            '    2
# 0   1  This is a random; 'sentence', just for explora...         only    4
# 0   1  This is a random; 'sentence', just for explora...          ',     3
# 0   1  This is a random; 'sentence', just for explora...          don    3
# 0   1  This is a random; 'sentence', just for explora...            '    1
# 0   1  This is a random; 'sentence', just for explora...            t    1
# 0   1  This is a random; 'sentence', just for explora...                 1
# 0   1  This is a random; 'sentence', just for explora...       bother    6
# 0   1  This is a random; 'sentence', just for explora...            -    1
# 0   1  This is a random; 'sentence', just for explora...        about    5
# 0   1  This is a random; 'sentence', just for explora...            /    1
# 0   1  This is a random; 'sentence', just for explora...          the    3
# 0   1  This is a random; 'sentence', just for explora...                 1
# 0   1  This is a random; 'sentence', just for explora...      grammer    7
# 0   1  This is a random; 'sentence', just for explora...                 1
# 0   1  This is a random; 'sentence', just for explora...      mistake    7
# 0   1  This is a random; 'sentence', just for explora...            .    1
#
#    span_end  span_beg      span
# 0         0         0    [0, 0]
# 0         4         0    [0, 4]
# 0         5         4    [4, 5]
# 0         7         5    [5, 7]
# 0         8         7    [7, 8]
# 0         9         8    [8, 9]
# 0        10         9   [9, 10]
# 0        16        10  [10, 16]
# 0        19        16  [16, 19]
# 0        27        19  [19, 27]
# 0        30        27  [27, 30]
# 0        34        30  [30, 34]
# 0        35        34  [34, 35]
# 0        38        35  [35, 38]
# 0        39        38  [38, 39]
# 0        50        39  [39, 50]
# 0        52        50  [50, 52]
# 0        56        52  [52, 56]
# 0        59        56  [56, 59]
# 0        62        59  [59, 62]
# 0        63        62  [62, 63]
# 0        64        63  [63, 64]
# 0        65        64  [64, 65]
# 0        71        65  [65, 71]
# 0        72        71  [71, 72]
# 0        77        72  [72, 77]
# 0        78        77  [77, 78]
# 0        81        78  [78, 81]
# 0        82        81  [81, 82]
# 0        89        82  [82, 89]
# 0        90        89  [89, 90]
# 0        97        90  [90, 97]
# 0        98        97  [97, 98]

# %% [markdown]
# ## Preprocessing on sentence split and span.

# %%
df_entities = pd.read_json(f"{DIR_DATASET}/NER_entities_labelled.jsonl", orient="records", encoding="utf-8", encoding_errors="ignore", lines=True)

# Preview. 
df_entities
# Out:
#       id                                               text  \
# 0      1  The FOMC has committed to using rates, not ass...
# 1      2  He noted that the FOMC made exceptional progre...
# 2      3  "Many participants noted that one or more 50 b...
# 3      4  The FOMC meets eight times a year todiscuss mo...
# 4      5  The 12 members of theFOMCmeet eight times a ye...
# ..   ...                                                ...
# 564  565  TradeStation data shows that the S&P 500 Commu...
# 565  566  Facebook, Netflix and Alphabet, parent of Goog...
# 566  567  Analysts do not expect a big market move when ...
# 567  568  The new communications services industry will ...
# 568  569  The forward multiple on the new sector could b...
#
#                                              relations  \
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 1    [{'id': 23, 'from_id': 3, 'to_id': 4951, 'type...
# 2    [{'id': 31, 'from_id': 5933, 'to_id': 13, 'typ...
# 3    [{'id': 15, 'from_id': 23, 'to_id': 36, 'type'...
# 4    [{'id': 19, 'from_id': 38, 'to_id': 40, 'type'...
# ..                                                 ...
# 564                                                 []
# 565                                                 []
# 566                                                 []
# 567                                                 []
# 568                                                 []
#
#                                               entities label
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]
# 1    [{'id': 3, 'start_offset': 18, 'end_offset': 2...  [[]]
# 2    [{'id': 13, 'start_offset': 268, 'end_offset':...  [[]]
# 3    [{'id': 23, 'start_offset': 4, 'end_offset': 8...  [[]]
# 4    [{'id': 38, 'start_offset': 21, 'end_offset': ...  [[]]
# ..                                                 ...   ...
# 564  [{'id': 5864, 'start_offset': 0, 'end_offset':...  [[]]
# 565  [{'id': 5876, 'start_offset': 0, 'end_offset':...  [[]]
# 566  [{'id': 5887, 'start_offset': 0, 'end_offset':...  [[]]
# 567  [{'id': 5901, 'start_offset': 8, 'end_offset':...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
#
# [569 rows x 5 columns]

# %% [markdown]
# ### Keep the labels on separately for processing later.

# %%
# Keep a record of the labels separately for processing later. 
label_relation = df_entities[["id", "relations"]].values
label_entities = df_entities[["id", "entities"]].values

# Preview. 
label_relation[:5], label_entities[:5]
# Out:
# (array([[1,
#          list([{'id': 21, 'from_id': 1, 'to_id': 5914, 'type': 'CAUSE'}, {'id': 22, 'from_id': 1, 'to_id': 5918, 'type': 'CAUSE'}])],
#         [2,
#          list([{'id': 23, 'from_id': 3, 'to_id': 4951, 'type': 'STATUS'}, {'id': 24, 'from_id': 3, 'to_id': 5919, 'type': 'STATUS'}, {'id': 29, 'from_id': 5932, 'to_id': 4952, 'type': 'OCCUR_AT'}, {'id': 30, 'from_id': 5921, 'to_id': 5932, 'type': 'OCCUR_AT'}])],
#         [3,
#          list([{'id': 31, 'from_id': 5933, 'to_id': 13, 'type': 'OCCUR_AT'}, {'id': 32, 'from_id': 5926, 'to_id': 5927, 'type': 'EFFECT'}, {'id': 33, 'from_id': 5936, 'to_id': 18, 'type': 'EFFECT'}, {'id': 34, 'from_id': 5936, 'to_id': 5934, 'type': 'OCCUR_AT'}])],
#         [4,
#          list([{'id': 15, 'from_id': 23, 'to_id': 36, 'type': 'OCCUR_AT'}, {'id': 39, 'from_id': 27, 'to_id': 28, 'type': 'ACT_ON'}, {'id': 40, 'from_id': 29, 'to_id': 5938, 'type': 'ACT_ON'}, {'id': 41, 'from_id': 30, 'to_id': 31, 'type': 'ACT_ON'}, {'id': 42, 'from_id': 30, 'to_id': 32, 'type': 'ACT_ON'}, {'id': 43, 'from_id': 23, 'to_id': 27, 'type': 'CAUSE'}])],
#         [5,
#          list([{'id': 19, 'from_id': 38, 'to_id': 40, 'type': 'OCCUR_AT'}, {'id': 44, 'from_id': 38, 'to_id': 5939, 'type': 'CAUSE'}, {'id': 45, 'from_id': 5939, 'to_id': 45, 'type': 'ACT_ON'}])]],
#        dtype=object),
#  array([[1,
#          list([{'id': 1, 'start_offset': 4, 'end_offset': 8, 'label': 'ORG'}, {'id': 3420, 'start_offset': 43, 'end_offset': 49, 'label': 'OBJ'}, {'id': 5913, 'start_offset': 9, 'end_offset': 22, 'label': 'STAT'}, {'id': 5914, 'start_offset': 63, 'end_offset': 78, 'label': 'ECON'}, {'id': 5916, 'start_offset': 26, 'end_offset': 31, 'label': 'ACT'}, {'id': 5918, 'start_offset': 32, 'end_offset': 37, 'label': 'ECON'}])],
#         [2,
#          list([{'id': 3, 'start_offset': 18, 'end_offset': 22, 'label': 'ORG'}, {'id': 4951, 'start_offset': 23, 'end_offset': 48, 'label': 'STAT'}, {'id': 4952, 'start_offset': 155, 'end_offset': 161, 'label': 'TIME'}, {'id': 5919, 'start_offset': 80, 'end_offset': 95, 'label': 'STAT'}, {'id': 5920, 'start_offset': 130, 'end_offset': 137, 'label': 'STAT'}, {'id': 5921, 'start_offset': 109, 'end_offset': 123, 'label': 'OBJ'}, {'id': 5931, 'start_offset': 52, 'end_offset': 64, 'label': 'EVE'}, {'id': 5932, 'start_offset': 142, 'end_offset': 154, 'label': 'EVE'}])],
#         [3,
#          list([{'id': 13, 'start_offset': 268, 'end_offset': 276, 'label': 'TIME'}, {'id': 14, 'start_offset': 173, 'end_offset': 181, 'label': 'STAT'}, {'id': 15, 'start_offset': 185, 'end_offset': 196, 'label': 'STAT'}, {'id': 18, 'start_offset': 57, 'end_offset': 66, 'label': 'STAT'}, {'id': 5926, 'start_offset': 144, 'end_offset': 153, 'label': 'ECON'}, {'id': 5927, 'start_offset': 154, 'end_offset': 172, 'label': 'STAT'}, {'id': 5928, 'start_offset': 229, 'end_offset': 258, 'label': 'ORG'}, {'id': 5929, 'start_offset': 262, 'end_offset': 266, 'label': 'ORG'}, {'id': 5933, 'start_offset': 277, 'end_offset': 286, 'label': 'EVE'}, {'id': 5934, 'start_offset': 111, 'end_offset': 126, 'label': 'EVE'}, {'id': 5935, 'start_offset': 212, 'end_offset': 219, 'label': 'ECON'}, {'id': 5936, 'start_offset': 37, 'end_offset': 56, 'label': 'MEAS'}, {'id': 5937, 'start_offset': 6, 'end_offset': 18, 'label': 'ROLE'}])],
#         [4,
#          list([{'id': 23, 'start_offset': 4, 'end_offset': 8, 'label': 'ORG'}, {'id': 24, 'start_offset': 9, 'end_offset': 14, 'label': 'ACT'}, {'id': 27, 'start_offset': 34, 'end_offset': 43, 'label': 'ACT'}, {'id': 28, 'start_offset': 44, 'end_offset': 59, 'label': 'ECON'}, {'id': 29, 'start_offset': 69, 'end_offset': 75, 'label': 'ACT'}, {'id': 30, 'start_offset': 114, 'end_offset': 120, 'label': 'ACT'}, {'id': 31, 'start_offset': 121, 'end_offset': 136, 'label': 'ECON'}, {'id': 32, 'start_offset': 141, 'end_offset': 151, 'label': 'ECON'}, {'id': 36, 'start_offset': 15, 'end_offset': 33, 'label': 'TIME'}, {'id': 5938, 'start_offset': 76, 'end_offset': 109, 'label': 'OBJ'}])],
#         [5,
#          list([{'id': 38, 'start_offset': 21, 'end_offset': 25, 'label': 'ORG'}, {'id': 39, 'start_offset': 25, 'end_offset': 29, 'label': 'ACT'}, {'id': 40, 'start_offset': 30, 'end_offset': 48, 'label': 'TIME'}, {'id': 44, 'start_offset': 99, 'end_offset': 108, 'label': 'TIME'}, {'id': 45, 'start_offset': 109, 'end_offset': 124, 'label': 'ECON'}, {'id': 5939, 'start_offset': 49, 'end_offset': 59, 'label': 'ACT'}, {'id': 5940, 'start_offset': 84, 'end_offset': 95, 'label': 'STAT'}])]],
#        dtype=object))

# %% [markdown]
# ### Process sentence split and span.

# %%
# Split by boundary between alphabets and non-alphabet. 
# Example (random; token) will be come [random, ; , token]. 
# This will not ignore white spaces. 
df_entities["token"] = df_entities["text"].str.split(r"\b") 

# Preview. 
df_entities
# Out:
#       id                                               text  \
# 0      1  The FOMC has committed to using rates, not ass...
# 1      2  He noted that the FOMC made exceptional progre...
# 2      3  "Many participants noted that one or more 50 b...
# 3      4  The FOMC meets eight times a year todiscuss mo...
# 4      5  The 12 members of theFOMCmeet eight times a ye...
# ..   ...                                                ...
# 564  565  TradeStation data shows that the S&P 500 Commu...
# 565  566  Facebook, Netflix and Alphabet, parent of Goog...
# 566  567  Analysts do not expect a big market move when ...
# 567  568  The new communications services industry will ...
# 568  569  The forward multiple on the new sector could b...
#
#                                              relations  \
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 1    [{'id': 23, 'from_id': 3, 'to_id': 4951, 'type...
# 2    [{'id': 31, 'from_id': 5933, 'to_id': 13, 'typ...
# 3    [{'id': 15, 'from_id': 23, 'to_id': 36, 'type'...
# 4    [{'id': 19, 'from_id': 38, 'to_id': 40, 'type'...
# ..                                                 ...
# 564                                                 []
# 565                                                 []
# 566                                                 []
# 567                                                 []
# 568                                                 []
#
#                                               entities label  \
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]
# 1    [{'id': 3, 'start_offset': 18, 'end_offset': 2...  [[]]
# 2    [{'id': 13, 'start_offset': 268, 'end_offset':...  [[]]
# 3    [{'id': 23, 'start_offset': 4, 'end_offset': 8...  [[]]
# 4    [{'id': 38, 'start_offset': 21, 'end_offset': ...  [[]]
# ..                                                 ...   ...
# 564  [{'id': 5864, 'start_offset': 0, 'end_offset':...  [[]]
# 565  [{'id': 5876, 'start_offset': 0, 'end_offset':...  [[]]
# 566  [{'id': 5887, 'start_offset': 0, 'end_offset':...  [[]]
# 567  [{'id': 5901, 'start_offset': 8, 'end_offset':...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
#
#                                                  token
# 0    [, The,  , FOMC,  , has,  , committed,  , to, ...
# 1    [, He,  , noted,  , that,  , the,  , FOMC,  , ...
# 2    [", Many,  , participants,  , noted,  , that, ...
# 3    [, The,  , FOMC,  , meets,  , eight,  , times,...
# 4    [, The,  , 12,  , members,  , of,  , theFOMCme...
# ..                                                 ...
# 564  [, TradeStation,  , data,  , shows,  , that,  ...
# 565  [, Facebook, , , Netflix,  , and,  , Alphabet,...
# 566  [, Analysts,  , do,  , not,  , expect,  , a,  ...
# 567  [, The,  , new,  , communications,  , services...
# 568  [, The,  , forward,  , multiple,  , on,  , the...
#
# [569 rows x 6 columns]

# %%
# Expand the list of token into subsequent rows. 
df_token = df_entities.explode(column="token") 

# Preview. 
df_token
# Out:
#       id                                               text  \
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# ..   ...                                                ...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
#
#                                              relations  \
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# ..                                                 ...
# 568                                                 []
# 568                                                 []
# 568                                                 []
# 568                                                 []
# 568                                                 []
#
#                                               entities label token
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]   The
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]  FOMC
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]
# ..                                                 ...   ...   ...
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]    at
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]  CFRA
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]     .
#
# [29837 rows x 6 columns]

# %%
# Get the str length to calculate span (str indices) at the start and end later. 
# We need span to extract the entities. Other third-party NLP pipelines 
# also require spans as input. 
df_token["len"] = df_token["token"].str.len() 

# Get the span for each token for each sentence. 
df_token["span_end"] = df_token.groupby("id").agg(span_end=pd.NamedAgg(column="len", aggfunc=np.cumsum)) 
df_token["span_beg"] = df_token.groupby("id")["span_end"].shift(periods=1) 
df_token["span_beg"] = df_token["span_beg"].fillna(0.0).astype(int) 
df_token["span"] = df_token[["span_beg", "span_end"]].values.tolist() 

# Preview. 
df_token
# Out:
#       id                                               text  \
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# ..   ...                                                ...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
#
#                                              relations  \
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# ..                                                 ...
# 568                                                 []
# 568                                                 []
# 568                                                 []
# 568                                                 []
# 568                                                 []
#
#                                               entities label token  len  \
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]          0
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]   The    3
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]          1
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]  FOMC    4
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]          1
# ..                                                 ...   ...   ...  ...
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]          1
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]    at    2
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]          1
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]  CFRA    4
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]     .    1
#
#      span_end  span_beg        span
# 0           0         0      [0, 0]
# 0           3         0      [0, 3]
# 0           4         3      [3, 4]
# 0           8         4      [4, 8]
# 0           9         8      [8, 9]
# ..        ...       ...         ...
# 568       214       213  [213, 214]
# 568       216       214  [214, 216]
# 568       217       216  [216, 217]
# 568       221       217  [217, 221]
# 568       222       221  [221, 222]
#
# [29837 rows x 10 columns]

# %% [markdown]
# ## Preprocess tokens and add in the entities.

# %% [markdown]
# ### Process the tokens.

# %%
# Add new column to store the entities label. 
df_token["tag_entity"] = "O" 

# To track error for attached tokens when proceessing the labels. 
dict_sent_id_error = defaultdict(lambda: []) 
dict_sent_id_error_count = defaultdict(lambda: 0)

# %%
# Store the processed tokens in the new dataframe instead to avoid overwriting. 
df_processed_token = pd.DataFrame() 

# Each (label_entities) contain [ sent_id: Int, entities:List[ Dict[Text, Any] ] ]. 
for label in label_entities: 
	sent_id, entities = tuple(label) 

	# Partition the sentence from other sentences to process 1 sentence at a time. 
	boo_sent_id = df_token["id"] == sent_id 
	df_process_sent = df_token.loc[boo_sent_id, :].copy() 

	# Use this to track the overlapping span. 
	span_tracking = set() 

	for entity in entities: 
		# Skip the processing if there's an overlap. It has already been processed. 
		start_offset, end_offset = entity["start_offset"], entity["end_offset"]

		# Track and ignore the overlapped span since the processing has been done. 
		if (start_offset in span_tracking) and ((end_offset - 1) in span_tracking): 
			dict_sent_id_error[sent_id].append({"sent_id": sent_id, "entity": entity}) 
			dict_sent_id_error_count[sent_id] += 1 
			continue 

		# Set conditions for filter. 
		# 1) Filter on sentences. 
		# 2) Filter spacing. 
		# 3) Find the token(s) in between the span range. 
		boo_spacing = df_process_sent["token"].str.strip() != "" 
		boo_span = df_process_sent["span_beg"].between(start_offset, end_offset, inclusive="left") 
		boo_conditions = boo_spacing & boo_span 

		# Get the # of token(s) after the filtering. 
		nrows = boo_conditions.sum() 

		# If can't detect the token(s), split the attached token into separate rows. 
		# Also record the error for debugging later. 
		if nrows == 0: 
			dict_sent_id_error[sent_id].append({"sent_id": sent_id, "entity": entity}) 
			dict_sent_id_error_count[sent_id] += 1
			
			# Since (start_offset) and (end_offset) cannot get the due to incorrect span, 
			# get the range of tokens between the incorrect start and end span and process them. 
			boo_upper_bound = df_process_sent["span_beg"] < end_offset
			boo_lower_bound = df_process_sent["span_end"] > start_offset 
			boo_conditions = boo_spacing & boo_upper_bound & boo_lower_bound 

			# For debugging. 
			print("SENT:", sent_id)
			print("TOKN:", df_process_sent.loc[boo_conditions, "token"]) 

			# The following algorithm only assumes 1 attached token. It only process 1 token or row. 
			# Example (TheFOMCmember). Not (TheFOMCmember, makeFFR), which will be 2 tokens or rows. 

			# Split attached token into separate tokens. Extract the key token within the 
			# attached token. The key token should be in the middle. Key token refers to 
			# the one not being labelled as "O". 
			span_beg, span_end = (
				df_process_sent.loc[boo_conditions, "span_beg"].values[0], 
				df_process_sent.loc[boo_conditions, "span_end"].values[0], 
			)
			token_attached = df_process_sent.loc[boo_conditions, "token"].values[0] 

			# Track the overlapping span. 
			span_tracking = span_tracking.union(set(i for i in range(span_beg, span_end))) 

			# Recalculate the span. 
			span_token_1st_end = start_offset - span_beg 
			span_token_2nd_end = span_token_1st_end + (end_offset - start_offset) 

			# Reassign the tokens. 
			token_attached_sep = [
				token_attached[:span_token_1st_end], 
				token_attached[span_token_1st_end:span_token_2nd_end], 
				token_attached[span_token_2nd_end:], 
			]

			# Reassign the start of the span (the indices). 
			token_span_beg_sep = [
				span_beg, 
				span_beg + span_token_1st_end, 
				span_beg + span_token_1st_end + (end_offset - start_offset), 
			]

			# Reassign the end of the span (the indices). 
			token_span_end_sep = [
				span_beg + span_token_1st_end, 
				span_beg + span_token_1st_end + (end_offset - start_offset), 
				span_end, 
			]

			# Need to do this so that you can add a list object together with the integers. 
			# The original dtype is interger. 
			df_process_sent.loc[boo_conditions, "span_beg"] = df_process_sent.loc[boo_conditions, "span_beg"].astype("object")
			df_process_sent.loc[boo_conditions, "span_end"] = df_process_sent.loc[boo_conditions, "span_end"].astype("object")

			# Need double square brackets due to (pandas) error. 
			# The outcome will be [[item, item, item]]. 
			df_process_sent.loc[boo_conditions, "token"] = [[token_attached_sep]] 
			df_process_sent.loc[boo_conditions, "span_beg"] = [[token_span_beg_sep]] 
			df_process_sent.loc[boo_conditions, "span_end"] = [[token_span_end_sep]] 

			# Need to do the (explode) twice since we have 2 square brackets. 
			cols_explode = ["token", "span_beg", "span_end"]
			df_process_sent = df_process_sent.explode(cols_explode).explode(cols_explode) 

		# Sort it to ensure the order is correct. 
		df_process_sent = df_process_sent.sort_values(by=["id", "span_beg", "span_end"], ascending=True) 

	# Consolidate all the processed tokens for the attached ones. 
	df_processed_token = pd.concat([df_processed_token, df_process_sent], axis="index")
# Out:
# SENT: 5
# TOKN: 4    theFOMCmeet
# Name: token, dtype: object
# SENT: 37
# TOKN: 36    bondclimbed
# Name: token, dtype: object
# SENT: 38
# TOKN: 37    noterose
# Name: token, dtype: object
# SENT: 57
# TOKN: 56    latestinflationary
# Name: token, dtype: object
# SENT: 60
# TOKN: 59    arecent
# Name: token, dtype: object
# SENT: 67
# TOKN: 66    ofinflationthat
# Name: token, dtype: object
# SENT: 70
# TOKN: 69    TheISM
# Name: token, dtype: object
# SENT: 70
# TOKN: 69    andServices
# Name: token, dtype: object
# SENT: 70
# TOKN: 69    BusinessManufacturing
# Name: token, dtype: object
# SENT: 72
# TOKN: 71    themanufacturing
# Name: token, dtype: object
# SENT: 72
# TOKN: 71    ISMReport
# Name: token, dtype: object
# SENT: 72
# TOKN: 71    latestManufacturing
# Name: token, dtype: object
# SENT: 77
# TOKN: 76    andinventories
# Name: token, dtype: object
# SENT: 80
# TOKN: 79    BusinessManufacturing
# Name: token, dtype: object
# SENT: 87
# TOKN: 86    latestServices
# Name: token, dtype: object
# SENT: 87
# TOKN: 86    ISMReport
# Name: token, dtype: object
# SENT: 87
# TOKN: 86    sectorgrew
# Name: token, dtype: object
# SENT: 106
# TOKN: 105    theBLS
# Name: token, dtype: object
# SENT: 115
# TOKN: 114    Michiganreported
# Name: token, dtype: object
# SENT: 124
# TOKN: 123    Fedraisedinterest
# Name: token, dtype: object
# SENT: 128
# TOKN: 127    measuresprice
# Name: token, dtype: object
# SENT: 131
# TOKN: 130    Reservereleased
# Name: token, dtype: object
# SENT: 131
# TOKN: 130    thatprices
# Name: token, dtype: object
# SENT: 135
# TOKN: 134    theFOMCcloser
# Name: token, dtype: object
# SENT: 136
# TOKN: 135    whenconsumerspay
# Name: token, dtype: object
# SENT: 143
# TOKN: 142    spervasive
# Name: token, dtype: object
# SENT: 154
# TOKN: 153    bankspay
# Name: token, dtype: object
# SENT: 155
# TOKN: 154    anovernightbasis
# Name: token, dtype: object
# SENT: 161
# TOKN: 160    thepetroleumpolicies
# Name: token, dtype: object
# SENT: 178
# TOKN: 177    itsannouncement
# Name: token, dtype: object
# SENT: 180
# TOKN: 179    AmazonandTesla
# Name: token, dtype: object
# SENT: 182
# TOKN: 181    ofAlphabet
# Name: token, dtype: object
# SENT: 182
# TOKN: 181    andTeslaall
# Name: token, dtype: object
# SENT: 187
# TOKN: 186    orconsolidatedwith
# Name: token, dtype: object
# SENT: 193
# TOKN: 192    toreducethe
# Name: token, dtype: object
# SENT: 195
# TOKN: 194    todividends
# Name: token, dtype: object
# SENT: 202
# TOKN: 201    ithadupsized
# Name: token, dtype: object
# SENT: 207
# TOKN: 206    Infinanceandlaw
# Name: token, dtype: object
# SENT: 207
# TOKN: 206    byshareholders
# Name: token, dtype: object
# SENT: 207
# TOKN: 206    thesharesof
# Name: token, dtype: object
# SENT: 207
# TOKN: 206    acorporationwhich
# Name: token, dtype: object
# SENT: 210
# TOKN: 209    includingAmazon
# Name: token, dtype: object
# SENT: 210
# TOKN: 209    andGrubhub
# Name: token, dtype: object
# SENT: 223
# TOKN: 222    andMeta
# Name: token, dtype: object
# SENT: 228
# TOKN: 227    Qualcommannounced
# Name: token, dtype: object
# SENT: 229
# TOKN: 228    theannouncement
# Name: token, dtype: object
# SENT: 234
# TOKN: 233    DevicesAMDas
# Name: token, dtype: object
# SENT: 300
# TOKN: 299    retailers
# Name: token, dtype: object
# SENT: 451
# TOKN: 450    Martindelivered
# Name: token, dtype: object

# %%
# Preview. 
df_processed_token
# Out:
#       id                                               text  \
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# ..   ...                                                ...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
#
#                                              relations  \
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# ..                                                 ...
# 568                                                 []
# 568                                                 []
# 568                                                 []
# 568                                                 []
# 568                                                 []
#
#                                               entities label token  len  \
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]          0
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]   The    3
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]          1
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]  FOMC    4
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]          1
# ..                                                 ...   ...   ...  ...
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]          1
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]    at    2
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]          1
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]  CFRA    4
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]     .    1
#
#     span_end span_beg        span tag_entity
# 0          0        0      [0, 0]          O
# 0          3        0      [0, 3]          O
# 0          4        3      [3, 4]          O
# 0          8        4      [4, 8]          O
# 0          9        8      [8, 9]          O
# ..       ...      ...         ...        ...
# 568      214      213  [213, 214]          O
# 568      216      214  [214, 216]          O
# 568      217      216  [216, 217]          O
# 568      221      217  [217, 221]          O
# 568      222      221  [221, 222]          O
#
# [29935 rows x 11 columns]

# %% [markdown]
# ### Update the token span.

# %%
# Need to recalculate the str length after processing the attached tokens. 
# We probably will not use the (len) and (span) columns so we can skip this step also. 
df_processed_token["len"] = df_processed_token["token"].str.len() 
df_processed_token["span"] = df_processed_token[["span_beg", "span_end"]].values.tolist() 

# Preview. 
df_processed_token
# Out:
#       id                                               text  \
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# ..   ...                                                ...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
#
#                                              relations  \
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# ..                                                 ...
# 568                                                 []
# 568                                                 []
# 568                                                 []
# 568                                                 []
# 568                                                 []
#
#                                               entities label token  len  \
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]          0
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]   The    3
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]          1
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]  FOMC    4
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]          1
# ..                                                 ...   ...   ...  ...
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]          1
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]    at    2
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]          1
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]  CFRA    4
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]     .    1
#
#     span_end span_beg        span tag_entity
# 0          0        0      [0, 0]          O
# 0          3        0      [0, 3]          O
# 0          4        3      [3, 4]          O
# 0          8        4      [4, 8]          O
# 0          9        8      [8, 9]          O
# ..       ...      ...         ...        ...
# 568      214      213  [213, 214]          O
# 568      216      214  [214, 216]          O
# 568      217      216  [216, 217]          O
# 568      221      217  [217, 221]          O
# 568      222      221  [221, 222]          O
#
# [29935 rows x 11 columns]

# %%
# Check which sentences contain attached tokens for the ones 
# not labelled as "O". 
dict_sent_id_error_count
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {5: 2,
#              37: 1,
#              38: 1,
#              57: 1,
#              60: 1,
#              67: 1,
#              70: 3,
#              72: 3,
#              77: 1,
#              80: 1,
#              87: 4,
#              106: 1,
#              115: 1,
#              124: 1,
#              128: 1,
#              131: 2,
#              135: 1,
#              136: 1,
#              143: 1,
#              154: 1,
#              155: 1,
#              161: 2,
#              178: 1,
#              180: 1,
#              182: 2,
#              187: 1,
#              193: 1,
#              195: 1,
#              202: 1,
#              207: 4,
#              210: 2,
#              223: 1,
#              228: 1,
#              229: 1,
#              234: 1,
#              300: 2,
#              451: 1})

# %%
# For debugging only. Change the ID to check specific sentence. 
df_processed_token.loc[df_processed_token["id"] == 5, ["entities", "token", "len", "span_beg", "span_end", "span", "tag_entity"]].head(30)
# Out:
#                                             entities    token  len span_beg  \
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             0        0
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...      The    3        0
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1        3
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...       12    2        4
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1        6
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...  members    7        7
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       14
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...       of    2       15
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       17
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...      the    3       18
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...     FOMC    4       21
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...     meet    4       25
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       29
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...    eight    5       30
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       35
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...    times    5       36
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       41
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...        a    1       42
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       43
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...     year    4       44
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       48
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...       to    2       49
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       51
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...  discuss    7       52
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       59
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...  whether    7       60
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       67
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...    there    5       68
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       73
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...   should    6       74
#
#   span_end      span tag_entity
# 4        0    [0, 0]          O
# 4        3    [0, 3]          O
# 4        4    [3, 4]          O
# 4        6    [4, 6]          O
# 4        7    [6, 7]          O
# 4       14   [7, 14]          O
# 4       15  [14, 15]          O
# 4       17  [15, 17]          O
# 4       18  [17, 18]          O
# 4       21  [18, 21]          O
# 4       25  [21, 25]          O
# 4       29  [25, 29]          O
# 4       30  [29, 30]          O
# 4       35  [30, 35]          O
# 4       36  [35, 36]          O
# 4       41  [36, 41]          O
# 4       42  [41, 42]          O
# 4       43  [42, 43]          O
# 4       44  [43, 44]          O
# 4       48  [44, 48]          O
# 4       49  [48, 49]          O
# 4       51  [49, 51]          O
# 4       52  [51, 52]          O
# 4       59  [52, 59]          O
# 4       60  [59, 60]          O
# 4       67  [60, 67]          O
# 4       68  [67, 68]          O
# 4       73  [68, 73]          O
# 4       74  [73, 74]          O
# 4       80  [74, 80]          O

# %% [markdown]
# ### Add in the entities.

# %%
# If you want to include BIO in the labels, use these variables. 
dict_bio = defaultdict(lambda: "I-") 
dict_bio[0] = "B-" 

# Each (label_entities) contain [ sent_id: Int, entities:List[ Dict[Text, Any] ] ]. 
for label in label_entities: 
	sent_id, entities = tuple(label) 

	for entity in entities: 
		start_offset, end_offset = entity["start_offset"], entity["end_offset"]

		# Set conditions for filtering. 
		# 1) Filter on sentences. 
		# 2) Filter spacing. 
		# 3) Find the token(s) in between the span range. 
		boo_sent_id = df_processed_token["id"] == sent_id 
		boo_spacing = df_processed_token["token"].str.strip() != "" 
		boo_span = df_processed_token["span_beg"].between(start_offset, end_offset, inclusive="left") 
		boo_conditions = boo_sent_id & boo_spacing & boo_span 

		# Get the # of token(s). 
		nrows = boo_conditions.sum() 

		# If the length of the token is 1, simply assign the entity tag. 
		if nrows == 1: 
			df_processed_token.loc[boo_conditions, "tag_entity"] = f'''{dict_bio[0]}{entity["label"]}''' 

		# If there are 2 or more tokens, assign the same entity tag to each of them. 
		elif nrows > 1: 
			spaces = "" 
			tokens = df_processed_token.loc[boo_conditions, "token"].values

			tag_entity = [f'''{dict_bio[i]}{entity["label"]}''' for i, t in enumerate(tokens) if t.strip() != spaces] 
			df_processed_token.loc[boo_conditions, "tag_entity"] = tag_entity 


# Preview. 
df_processed_token
# Out:
#       id                                               text  \
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# 0      1  The FOMC has committed to using rates, not ass...
# ..   ...                                                ...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
# 568  569  The forward multiple on the new sector could b...
#
#                                              relations  \
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# 0    [{'id': 21, 'from_id': 1, 'to_id': 5914, 'type...
# ..                                                 ...
# 568                                                 []
# 568                                                 []
# 568                                                 []
# 568                                                 []
# 568                                                 []
#
#                                               entities label token  len  \
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]          0
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]   The    3
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]          1
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]  FOMC    4
# 0    [{'id': 1, 'start_offset': 4, 'end_offset': 8,...  [[]]          1
# ..                                                 ...   ...   ...  ...
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]          1
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]    at    2
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]          1
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]  CFRA    4
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]     .    1
#
#     span_end span_beg        span tag_entity
# 0          0        0      [0, 0]          O
# 0          3        0      [0, 3]          O
# 0          4        3      [3, 4]          O
# 0          8        4      [4, 8]        ORG
# 0          9        8      [8, 9]          O
# ..       ...      ...         ...        ...
# 568      214      213  [213, 214]          O
# 568      216      214  [214, 216]          O
# 568      217      216  [216, 217]          O
# 568      221      217  [217, 221]        ORG
# 568      222      221  [221, 222]          O
#
# [29935 rows x 11 columns]

# %%
# For debugging only. Change the ID to check specific sentence. 
df_processed_token.loc[df_processed_token["id"] == 5, ["entities", "token", "len", "span_beg", "span_end", "span", "tag_entity"]].head(30)
# Out:
#                                             entities    token  len span_beg  \
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             0        0
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...      The    3        0
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1        3
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...       12    2        4
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1        6
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...  members    7        7
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       14
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...       of    2       15
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       17
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...      the    3       18
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...     FOMC    4       21
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...     meet    4       25
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       29
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...    eight    5       30
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       35
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...    times    5       36
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       41
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...        a    1       42
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       43
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...     year    4       44
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       48
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...       to    2       49
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       51
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...  discuss    7       52
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       59
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...  whether    7       60
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       67
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...    there    5       68
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...             1       73
# 4  [{'id': 38, 'start_offset': 21, 'end_offset': ...   should    6       74
#
#   span_end      span tag_entity
# 4        0    [0, 0]          O
# 4        3    [0, 3]          O
# 4        4    [3, 4]          O
# 4        6    [4, 6]          O
# 4        7    [6, 7]          O
# 4       14   [7, 14]          O
# 4       15  [14, 15]          O
# 4       17  [15, 17]          O
# 4       18  [17, 18]          O
# 4       21  [18, 21]          O
# 4       25  [21, 25]        ORG
# 4       29  [25, 29]        ACT
# 4       30  [29, 30]          O
# 4       35  [30, 35]       TIME
# 4       36  [35, 36]          O
# 4       41  [36, 41]       TIME
# 4       42  [41, 42]          O
# 4       43  [42, 43]       TIME
# 4       44  [43, 44]          O
# 4       48  [44, 48]       TIME
# 4       49  [48, 49]          O
# 4       51  [49, 51]        ACT
# 4       52  [51, 52]          O
# 4       59  [52, 59]        ACT
# 4       60  [59, 60]          O
# 4       67  [60, 67]          O
# 4       68  [67, 68]          O
# 4       73  [68, 73]          O
# 4       74  [73, 74]          O
# 4       80  [74, 80]          O

# %% [markdown]
# ### Remove white spaces.

# %%
# Remove rows that contain white spaces. We don't need them for model training. 
# We didn't remove them at the start because we need to count them in the 
# start and end of span. Notice that we don't change the span even after we 
# remove the white spaces. 
df_final_output = df_processed_token[df_processed_token["token"].str.strip() != ""]

# Preview. 
df_final_output.tail(30)
# Out:
#       id                                               text relations  \
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
# 568  569  The forward multiple on the new sector could b...        []
#
#                                               entities label  \
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
# 568  [{'id': 4306, 'start_offset': 100, 'end_offset...  [[]]
#
#                  token  len span_end span_beg        span tag_entity
# 568                 ,     2       66       64    [64, 66]          O
# 568                 up    2       68       66    [66, 68]       STAT
# 568            sharply    7       76       69    [69, 76]       STAT
# 568               from    4       81       77    [77, 81]       STAT
# 568                the    3       85       82    [82, 85]          O
# 568              lower    5       91       86    [86, 91]       STAT
# 568             growth    6       98       92    [92, 98]       STAT
# 568                 ,     2      100       98   [98, 100]          O
# 568              value    5      105      100  [100, 105]       STAT
# 568                  -    1      106      105  [105, 106]       STAT
# 568           oriented    8      114      106  [106, 114]       STAT
# 568  telecommunication   17      132      115  [115, 132]       SECT
# 568             sector    6      139      133  [133, 139]          O
# 568               that    4      144      140  [140, 144]          O
# 568          currently    9      154      145  [145, 154]          O
# 568             trades    6      161      155  [155, 161]       MEAS
# 568                 at    2      164      162  [162, 164]       MEAS
# 568                 10    2      167      165  [165, 167]       MEAS
# 568                  .    1      168      167  [167, 168]       MEAS
# 568                 6x    2      170      168  [168, 170]       MEAS
# 568                 ,     2      172      170  [170, 172]          O
# 568              notes    5      177      172  [172, 177]          O
# 568            Lindsey    7      185      178  [178, 185]        PER
# 568               Bell    4      190      186  [186, 190]        PER
# 568                 ,     2      192      190  [190, 192]          O
# 568         investment   10      202      192  [192, 202]       ROLE
# 568         strategist   10      213      203  [203, 213]       ROLE
# 568                 at    2      216      214  [214, 216]          O
# 568               CFRA    4      221      217  [217, 221]        ORG
# 568                  .    1      222      221  [221, 222]          O

# %%
cols = ['id','text','token','span_beg','span_end','span','tag_entity']

df_final_output[cols].to_csv(f"{DIR_DATASET}/NER_entities_labelled.csv", index=False)
